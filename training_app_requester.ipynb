# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/My Drive')
# Out:
# ['20150512_200000.jpg',
#  'aug 10-aug 17',
#  'mumbai_three.pdf',
#  'Isomer_Test_Level-2-(not conducted yet)(pdf).pdf',
#  'orientations.gdoc',
#  'Screenshot (May 7, 2016 8:34:47 PM)',
#  'syska password.gdoc',
#  'Instructions.gdoc',
#  'Instructions (1).gdoc',
#  'Torrent InFo.gdoc',
#  'Instructions (2).gdoc',
#  'IMG_20160502_200320.jpg',
#  'Google Photos',
#  'Torrent Downloads From.gdoc',
#  'My Blog@ xpoztorrent.blogspot.com.gdoc',
#  'Android',
#  'Untitled.gdoc',
#  'My Blog @xpoztorrent.blogspot.com.gdoc',
#  'My Blog @xpoztorrent (1).blogspot.com.gdoc',
#  'README!!!.gdoc',
#  'ANDROID ZONE.gdoc',
#  'H.W. (INDEFINITE INTEGRAL).pdf',
#  'ordination 2011.pdf',
#  'ordination 2011 (1).pdf',
#  "China's Arguements .docx",
#  "China's Arguements .gdoc",
#  'PR00007014S.pdf',
#  'PRACTCE QUESTION ON AOD - Q.pdf',
#  'Jun 18, 2017 12-20 AM_8997',
#  'VidTrim_7467.webm',
#  'Document from pranjalsrv.pdf',
#  'Document from pranjalsrv (1).pdf',
# ...

# %%
import pandas as pd
all_truck = pd.read_csv('/content/drive/My Drive/all_truck.csv')

# %%
# all_request = all_truck.iloc[:100,:]

# for i in range(len(all_request)):
#   k = all_request.iloc[i,:]
#   data = {
#     "latitude": k['latitude'],
#     "longitude": k['longitude'],
#     "speed": k['speed'],
#     "direction": k['direction']
#   }
#   print(data)
# Out:
# {'latitude': 22.83018, 'longitude': 108.403201, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830149, 'longitude': 108.403222, 'speed': 2.0, 'direction': 96.0}
# {'latitude': 22.830147, 'longitude': 108.40325700000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830157, 'longitude': 108.40321499999999, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830182999999998, 'longitude': 108.40326999999999, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830234, 'longitude': 108.40326, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830174, 'longitude': 108.40325800000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830192999999998, 'longitude': 108.403252, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830136, 'longitude': 108.403241, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830174, 'longitude': 108.40323400000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.83021, 'longitude': 108.403252, 'speed': 0.0, 'direction': 0.0}
# ...

# %%
# !pip install pyrebase

# %%
import pyrebase

config = {
    "apiKey" :"AIzaSyBDuGgAoiVSWd94CCcRvG4RxVXEKiseQE0",
    "authDomain": "rota-hack.firebaseapp.com",
    "databaseURL": "https://rota-hack.firebaseio.com",
    "projectId": "rota-hack",
    "storageBucket": "",
    "messagingSenderId": "773137993672",
    "appId": "1:773137993672:web:44dc778baeadda816cfafd"
  }

firebase = pyrebase.initialize_app(config)
auth = firebase.auth()
db = firebase.database()

# %%
all_request = all_truck.iloc[:100,:]

for i in range(len(all_request)):
  k = all_request.iloc[i,:]
  data = {
    "latitude": k['latitude'],
    "longitude": k['longitude'],
    "speed": k['speed'],
    "direction": k['direction']
  }
  print(data)
  results = db.child("training").push(data)
# Out:
# {'latitude': 22.83018, 'longitude': 108.403201, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830149, 'longitude': 108.403222, 'speed': 2.0, 'direction': 96.0}
# {'latitude': 22.830147, 'longitude': 108.40325700000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830157, 'longitude': 108.40321499999999, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830182999999998, 'longitude': 108.40326999999999, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830234, 'longitude': 108.40326, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830174, 'longitude': 108.40325800000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830192999999998, 'longitude': 108.403252, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830136, 'longitude': 108.403241, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.830174, 'longitude': 108.40323400000001, 'speed': 0.0, 'direction': 0.0}
# {'latitude': 22.83021, 'longitude': 108.403252, 'speed': 0.0, 'direction': 0.0}
# ...
